# %% [markdown]
# # Procesado de resultados (+ logs PCSMOTE)
# Notebook parametrizable para analizar múltiples **modelos** y **datasets**.
#
# ## Instrucciones
# 1. Editá la celda de **Configuración** con tus rutas y listas de modelos/datasets.
# 2. Ejecutá las celdas en orden.
# 3. Si activás `EXPORTAR_EXCEL`, se generará un .xlsx con hojas por (modelo,dataset) y logs encontrados.
#
# **Convenciones de archivos**
#
# - Resultados: `codigo/resultados/resultados_[Modelo].csv`
# - Logs PCSMOTE: `codigo/datasets/datasets_aumentados/pcsmote/logs/log_pcsmote_[dataset]_D[d]_R[r]_P[p].csv`

# %%
# === Configuración ===
from pathlib import Path

from pathlib import Path

# Directorio actual del notebook
BASE = Path.cwd()

# Subir un nivel (de notebooks → codigo)
ROOT = BASE.parent

PATH_RESULTADOS = ROOT / "resultados"
PATH_LOGS = ROOT / "datasets" / "datasets_aumentados" / "pcsmote" / "logs"

# Lista de modelos a estudiar (usa exactamente estos nombres para mapear a archivos):
# 'LogisticRegression' -> resultados_LogisticRegression.csv
# 'RandomForest'       -> resultados_RandomForest.csv
# 'SVM'                -> resultados_SVM.csv
MODELOS = ['LogisticRegression', 'RandomForest', 'SVM']  # editá lo que necesites

# Lista de datasets a estudiar
DATASETS = ['glass','ecoli','wdbc','heart','statlog+shuttle']  # agregá más: ['glass','ecoli','wdbc','heart','statlog+shuttle', ... ]

# Cantidad de filas top por (modelo,dataset)
TOP_N = 2

# Exportación a Excel (opcional)
EXPORTAR_EXCEL = True
RUTA_XLSX_SALIDA = ROOT / "resultados" / "estudio_de_resultados.xlsx"

# %%
# === Funciones utilitarias ===
import os,json, re
import pandas as pd
from collections import defaultdict
from IPython.display import display

PREFERENCIAS_METRICAS = [
    'gmean_macro', 'f1_macro', 'roc_auc_macro_ovr',
    'balanced_accuracy', 'kappa', 'mcc', 'accuracy', 'score'
]

# Acumuladores
bloques_por_modelo: dict[str, list[tuple[str, pd.DataFrame]]] = defaultdict(list)
logs_encontrados: list[tuple[str, pd.DataFrame]] = []

# --- Función para ajustar nombres de hoja ---
nombres_usados = set()

def alias_modelo(nombre: str) -> str:
    s = normalizar_str(nombre)
    if s == "randomforest":
        return "RF"
    if s == "logisticregression":
        return "LR"
    return nombre  # SVM u otros

def ajustar_nombre(nombre: str) -> str:
    nombre = nombre[:31]  # Excel no admite > 31 caracteres
    if nombre in nombres_usados:
        base = nombre[:28]  # dejar espacio para sufijo
        i = 1
        nuevo = f"{base}{i}"
        while nuevo in nombres_usados:
            i += 1
            nuevo = f"{base}{i}"
        nombre = nuevo
    nombres_usados.add(nombre)
    return nombre

def normalizar_str(x: str) -> str:
    return str(x).strip().lower()

def cargar_resultados(path_resultados: Path, modelos: list[str]) -> pd.DataFrame:
    dfs = []
    for m in modelos:
        ruta = path_resultados / f"resultados_{m}.csv"
        if not ruta.exists():
            print(f"[!] No encontré {ruta}, continúo…")
            continue
        try:
            df = pd.read_csv(ruta, encoding="utf-8")
        except UnicodeDecodeError:
            df = pd.read_csv(ruta, encoding="latin1")
        df.columns = [str(c).strip().replace(" ","_").replace("-","_").replace("/","_").lower() for c in df.columns]
        if "modelo" not in df.columns:
            df["modelo"] = m
        dfs.append(df)
    if not dfs:
        raise FileNotFoundError("No se cargó ningún CSV.")
    return pd.concat(dfs, ignore_index=True)

def elegir_metrica(resultados):
    dataset = resultados['dataset']
    densidad = resultados['densidad']
    riesgo = resultados['riesgo']
    pureza = resultados['pureza']
    
    for i in range(len(dataset)):
        archivo_log = f"log_pcsmote_{dataset.iloc[i]}_D{densidad.iloc[i]}_R{riesgo.iloc[i]}_P{pureza.iloc[i]}.csv"
        archivo_log_path = os.path.join(PATH_LOGS, archivo_log)
        
        # Verificar si el archivo existe
        if os.path.exists(archivo_log_path):
            print(f"Encontrado archivo de log: {archivo_log_path}")
        else:
            print(f"No encontrado archivo de log: {archivo_log_path}")
    
    return 'cv_f1_macro'

def col_dataset_name(df: pd.DataFrame) -> str:
    for cand in ('dataset','nombre_dataset','dataset_name','ds','nombre'):
        if cand in df.columns:
            return cand
    raise ValueError("No encuentro columna de dataset ('dataset' o 'nombre_dataset').")

def top_n_por_modelo_dataset(df: pd.DataFrame, modelo: str, dataset: str, metrica: str | None, n: int=2) -> pd.DataFrame:
    sub = df[df['modelo'].map(normalizar_str) == normalizar_str(modelo)].copy()
    cd = col_dataset_name(df)
    sub = sub[sub[cd].map(normalizar_str) == normalizar_str(dataset)]
    if sub.empty:
        return sub
    if metrica is None or metrica not in sub.columns:
        return sub.head(n)
    return sub.sort_values(metrica, ascending=False).head(n)

def detectar_pcsmote(row: pd.Series) -> bool:
    for c in ['tecnica','sobremuestreo','oversampler','sampler','tecnica_sobremuestreo']:
        if c in row.index and isinstance(row[c], str) and row[c] and row[c].strip().lower() == 'pcsmote':
            return True
    for c in ['dataset_file','mejor_configuracion','config']:
        if c in row.index and isinstance(row[c], str) and 'pcsmote' in row[c].lower():
            return True
    return False

def limpiar_num(x: str) -> str:
    """
    Convierte strings tipo '25.0' en '25', deja otros valores igual.
    """
    try:
        f = float(x)
        if f.is_integer():
            return str(int(f))
        return str(f)
    except:
        return str(x).strip()

def extraer_drps_desde_fila(row: pd.Series):
    # 1) columnas explícitas
    d = str(row.get('densidad','')).strip() or None
    r = str(row.get('riesgo','')).strip() or None
    p = str(row.get('pureza','')).strip() or None
    if d and r and p:
        return limpiar_num(d), limpiar_num(r), limpiar_num(p)

    # 2) JSON o texto en mejor_configuracion
    txt = str(row.get('mejor_configuracion','') or '')
    if txt:
        try:
            j = json.loads(txt)
            if isinstance(j, dict) and 'raw' in j and isinstance(j['raw'], str):
                try:
                    j2 = json.loads(j['raw'].replace("'", '"'))
                    j = j2
                except Exception:
                    pass
            d = j.get('densidad') or j.get('D') or j.get('densidad_pct')
            r = j.get('riesgo')   or j.get('R')
            p = j.get('pureza')   or j.get('P')
            if d and r and p:
                return str(d), str(r), str(p)
        except Exception:
            pass
        # Regex fallback
        mD = re.search(r"_D([^_]+)", txt)
        mR = re.search(r"_R([^_]+)", txt)
        mP = re.search(r"_P([^_./\\]+)", txt)
        if mD and mR and mP:
            return mD.group(1), mR.group(1), mP.group(1)

    # 3) dataset_file del estilo pcsmote_glass_D25_R25_Pproporcion_train.csv
    for c in ['dataset_file','train_file','test_file','archivo']:
        val = row.get(c)
        if isinstance(val, str) and val:
            mD = re.search(r"_D([^_]+)", val)
            mR = re.search(r"_R([^_]+)", val)
            mP = re.search(r"_P([^_./\\]+)", val)
            if mD and mR and mP:
                return mD.group(1), mR.group(1), mP.group(1)
    return None

def buscar_log_pcsmote(path_logs: Path, dataset: str, d: str, r: str, p: str):
    target = f"log_pcsmote_{dataset}_D{d}_R{r}_P{p}.csv".lower()
    if not path_logs.exists():
        return None
    for f in path_logs.rglob('*.csv'):
        if f.name.lower() == target:
            return f
    return None

# %%
# === Carga de resultados y selección de métrica ===
resultados = cargar_resultados(PATH_RESULTADOS, MODELOS)
METRICA = elegir_metrica(resultados)
print('Métrica elegida para ordenar (desc):', METRICA)

# Inferimos columna dataset una vez
COL_DATASET = None
for cand in ('dataset','nombre_dataset','dataset_name','ds','nombre'):
    if cand in resultados.columns:
        COL_DATASET = cand
        break
if COL_DATASET is None:
    raise ValueError("No encuentro columna de dataset ('dataset' o 'nombre_dataset').")

resultados.head(3)  # preview
# Out:
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_shuttle_D75.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_shuttle_D75.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_shuttle_D75.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_shuttle_D75.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_shuttle_D75.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_Dnan_Rnan_Pnan.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_Dnan_Rnan_Pnan.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_shuttle_Dnan_Rnan_Pnan.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_Dnan_Rnan_Pnan.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_shuttle_D75.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_shuttle_D75.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_shuttle_D75.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_shuttle_D75.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_shuttle_D75.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_Dnan_Rnan_Pnan.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_Dnan_Rnan_Pnan.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_shuttle_Dnan_Rnan_Pnan.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_Dnan_Rnan_Pnan.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D25.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D50.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_D75.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D25.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D50.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_D75.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D25.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D50.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R25.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R25.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R50.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R50.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R75.0_Pentropia.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_D75.0_R75.0_Pproporcion.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_glass_Dnan_Rnan_Pnan.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_heart_Dnan_Rnan_Pnan.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_shuttle_Dnan_Rnan_Pnan.csv
# No encontrado archivo de log: c:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\datasets\datasets_aumentados\pcsmote\logs\log_pcsmote_wdbc_Dnan_Rnan_Pnan.csv
# Métrica elegida para ordenar (desc): cv_f1_macro
#   dataset       tipo  tecnica  densidad  riesgo      pureza  n_train  n_test  \
# 0   glass  aumentado  pcsmote      25.0    25.0    entropia      268      43
# 1   glass  aumentado  pcsmote      25.0    25.0  proporcion      171      43
# 2   glass  aumentado  pcsmote      25.0    50.0    entropia      268      43
#
#    n_features  es_grande  ...  cv_f1_macro  cv_balanced_accuracy    cv_mcc  \
# 0           9      False  ...     0.662340              0.723556  0.587720
# 1           9      False  ...     0.602214              0.638124  0.468332
# 2           9      False  ...     0.674365              0.728556  0.596165
#
#   cv_cohen_kappa  test_f1_macro  test_balanced_accuracy  test_mcc  \
# 0       0.579117       0.483100                0.646032  0.415484
# 1       0.458554       0.603416                0.686508  0.531865
# 2       0.587568       0.454874                0.618254  0.380637
#
#    test_cohen_kappa  search_time_sec  n_jobs_search
# 0          0.382507            2.864              4
# 1          0.520223            0.721              4
# 2          0.351050            0.484              4
#
# [3 rows x 24 columns]

# %%
# === Estudio por lotes (MODELOS x DATASETS) ===
from IPython.display import display
import pandas as pd

# Acumuladores para exportar
hojas_excel: dict[str, pd.DataFrame] = {}
logs_encontrados: list[tuple[str, pd.DataFrame]] = []

for modelo in MODELOS:
    for ds in DATASETS:
        print('='*90)
        print(f'Modelo: {modelo} | Dataset: {ds}')

        topN = top_n_por_modelo_dataset(resultados, modelo, ds, METRICA, n=TOP_N)

        # Fila base para este modelo/dataset
        base_row = resultados[
            (resultados['modelo'].map(normalizar_str) == normalizar_str(modelo)) &
            (resultados[COL_DATASET].map(normalizar_str) == normalizar_str(ds)) &
            (resultados['tipo'].map(normalizar_str) == 'base')
        ]

        # Concatenar topN + base (si existe)
        combinado = pd.concat([topN, base_row], ignore_index=True) if not base_row.empty else topN

        if combinado.empty:
            print(' -> Sin filas para esta combinación.')
            continue

        display(combinado)

        # Guardar bloque en la hoja del MODELO (una hoja por modelo; múltiples datasets)
        bloques_por_modelo[modelo].append((ds, combinado))

        # ---- Logs PCSMOTE (igual que antes) ----
        for idx, row in topN.iterrows():
            if detectar_pcsmote(row):
                drp = extraer_drps_desde_fila(row)
                if not drp:
                    print(f'   [Fila {idx}] PCSMOTE detectado pero no pude extraer (D,R,P).')
                    continue
                d, r, p = drp
                ds_norm = str(row[COL_DATASET]).strip().lower()
                log_path = buscar_log_pcsmote(PATH_LOGS, ds_norm, str(d), str(r), str(p))
                if log_path is None or not log_path.exists():
                    print(f'   [!] No se encontró log: log_pcsmote_{ds_norm}_D{d}_R{r}_P{p}.csv en {PATH_LOGS}')
                    continue
                try:
                    log_df = pd.read_csv(log_path)
                    print(f'   [+] Log leído: {log_path.name}  (filas={len(log_df)})')
                    display(log_df.head(10))

                    mstr = normalizar_str(modelo)
                    modelo_norm = "RF" if mstr == "randomforest" else ("LR" if mstr == "logisticregression" else modelo)
                    hoja_nombre = f'log_{modelo_norm}_{ds_norm}_{d}_{r}_{p}'

                    logs_encontrados.append((hoja_nombre, log_df))
                except Exception as e:
                    print(f'   [x] Error leyendo {log_path.name}: {e}')
# Out:
# ==========================================================================================
# Modelo: LogisticRegression | Dataset: glass
#   dataset       tipo  tecnica  densidad  riesgo    pureza  n_train  n_test  \
# 0   glass  aumentado  pcsmote      50.0    25.0  entropia      268      43
# 1   glass  aumentado  pcsmote      50.0    75.0  entropia      268      43
# 2   glass       base     base       NaN     NaN       NaN      149      65
#
#    n_features  es_grande  ...  cv_f1_macro  cv_balanced_accuracy    cv_mcc  \
# 0           9      False  ...     0.730344              0.770194  0.674097
# 1           9      False  ...     0.703746              0.741737  0.634411
# 2           9      False  ...     0.549947              0.603114  0.468413
#
#   cv_cohen_kappa  test_f1_macro  test_balanced_accuracy  test_mcc  \
# 0       0.664657       0.596265                0.746032  0.541635
# 1       0.627837       0.596265                0.746032  0.541635
# 2       0.445878       0.603764                0.694272  0.546051
#
#    test_cohen_kappa  search_time_sec  n_jobs_search
# 0          0.515573            0.493              4
# 1          0.515573            0.491              4
# 2          0.512957            0.641              4
#
# [3 rows x 24 columns]
#    [+] Log leído: log_pcsmote_glass_D50_R25_Pentropia.csv  (filas=6)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0   glass      1              56                48  no se sobremuestrea
# 1   glass      2              61                48  no se sobremuestrea
# 2   glass      3              14                48      sobremuestreada
# 3   glass      5              10                48      sobremuestreada
# 4   glass      6               7                48      sobremuestreada
# 5   glass      7              23                48      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1  sin_faltante(actual>=objetivo)                              0
# 2                              ok                             34
# 3                              ok                             38
# 4         insuficientes_filtradas                              0
# 5                              ok                             25
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             171              171        0.327485  ...              NaN
# 1             171              171        0.356725  ...              NaN
# 2             171              205        0.081871  ...              1.0
# 3             171              243        0.058480  ...              0.0
# 4             171              243        0.040936  ...              0.4
# 5             171              268        0.134503  ...              1.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                50.0              25.0         entropia
# 1              NaN                50.0              25.0         entropia
# 2         0.721928                50.0              25.0         entropia
# 3         0.908695                50.0              25.0         entropia
# 4         0.970951                50.0              25.0         entropia
# 5         0.000000                50.0              25.0         entropia
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
# 2                PCSMOTE                0.8            42             2d
# 3                PCSMOTE                0.8            42             2d
# 4                PCSMOTE                0.8            42             2d
# 5                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:20.002049
# 1  2025-08-20T00:20:20.002049
# 2  2025-08-20T00:20:20.046713
# 3  2025-08-20T00:20:20.072602
# 4  2025-08-20T00:20:20.084190
# 5  2025-08-20T00:20:20.125995
#
# [6 rows x 27 columns]
#    [+] Log leído: log_pcsmote_glass_D50_R75_Pentropia.csv  (filas=6)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0   glass      1              56                48  no se sobremuestrea
# 1   glass      2              61                48  no se sobremuestrea
# 2   glass      3              14                48      sobremuestreada
# 3   glass      5              10                48      sobremuestreada
# 4   glass      6               7                48      sobremuestreada
# 5   glass      7              23                48      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1  sin_faltante(actual>=objetivo)                              0
# 2                              ok                             34
# 3                              ok                             38
# 4         insuficientes_filtradas                              0
# 5                              ok                             25
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             171              171        0.327485  ...              NaN
# 1             171              171        0.356725  ...              NaN
# 2             171              205        0.081871  ...              1.0
# 3             171              243        0.058480  ...              0.0
# 4             171              243        0.040936  ...              0.4
# 5             171              268        0.134503  ...              1.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                50.0              75.0         entropia
# 1              NaN                50.0              75.0         entropia
# 2         0.721928                50.0              75.0         entropia
# 3         0.908695                50.0              75.0         entropia
# 4         0.970951                50.0              75.0         entropia
# 5         0.000000                50.0              75.0         entropia
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
# 2                PCSMOTE                0.8            42             2d
# 3                PCSMOTE                0.8            42             2d
# 4                PCSMOTE                0.8            42             2d
# 5                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:20.355378
# 1  2025-08-20T00:20:20.355378
# 2  2025-08-20T00:20:20.371021
# 3  2025-08-20T00:20:20.407391
# 4  2025-08-20T00:20:20.419469
# 5  2025-08-20T00:20:20.439729
#
# [6 rows x 27 columns]
# ==========================================================================================
# Modelo: LogisticRegression | Dataset: ecoli
#  -> Sin filas para esta combinación.
# ==========================================================================================
# Modelo: LogisticRegression | Dataset: wdbc
#   dataset       tipo  tecnica  densidad  riesgo    pureza  n_train  n_test  \
# 0    wdbc  aumentado  pcsmote      25.0    25.0  entropia      513     114
# 1    wdbc  aumentado  pcsmote      75.0    25.0  entropia      513     114
# 2    wdbc       base     base       NaN     NaN       NaN      398     171
#
#    n_features  es_grande  ...  cv_f1_macro  cv_balanced_accuracy    cv_mcc  \
# 0          30      False  ...     0.972068              0.970114  0.945801
# 1          30      False  ...     0.972068              0.970114  0.945801
# 2          30      False  ...     0.967913              0.967655  0.936618
#
#   cv_cohen_kappa  test_f1_macro  test_balanced_accuracy  test_mcc  \
# 0       0.944223       0.980956                0.976190  0.962622
# 1       0.944223       0.980956                0.976190  0.962622
# 2       0.935868       0.987515                0.987515  0.975029
#
#    test_cohen_kappa  search_time_sec  n_jobs_search
# 0          0.961924            4.860              4
# 1          0.961924            1.980              4
# 2          0.975029            5.386              4
#
# [3 rows x 24 columns]
#    [+] Log leído: log_pcsmote_wdbc_D25_R25_Pentropia.csv  (filas=2)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0    wdbc      0             285               228  no se sobremuestrea
# 1    wdbc      1             170               228      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1                              ok                             58
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             455              455        0.626374  ...              NaN
# 1             455              513        0.373626  ...              0.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                25.0              25.0         entropia
# 1              0.0                25.0              25.0         entropia
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:15.388961
# 1  2025-08-20T00:20:15.506615
#
# [2 rows x 27 columns]
#    [+] Log leído: log_pcsmote_wdbc_D75_R25_Pentropia.csv  (filas=2)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0    wdbc      0             285               228  no se sobremuestrea
# 1    wdbc      1             170               228      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1                              ok                             58
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             455              455        0.626374  ...              NaN
# 1             455              513        0.373626  ...              0.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                75.0              25.0         entropia
# 1              0.0                75.0              25.0         entropia
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:18.274574
# 1  2025-08-20T00:20:18.481260
#
# [2 rows x 27 columns]
# ==========================================================================================
# Modelo: LogisticRegression | Dataset: heart
#   dataset       tipo  tecnica  densidad  riesgo      pureza  n_train  n_test  \
# 0   heart  aumentado  pcsmote      75.0    25.0  proporcion      444      60
# 1   heart  aumentado  pcsmote      75.0    50.0  proporcion      444      60
# 2   heart       base     base       NaN     NaN         NaN      207      90
#
#    n_features  es_grande  ...  cv_f1_macro  cv_balanced_accuracy    cv_mcc  \
# 0          13      False  ...     0.551607              0.559953  0.595738
# 1          13      False  ...     0.548370              0.556177  0.590551
# 2          13      False  ...     0.312362              0.326200  0.309212
#
#   cv_cohen_kappa  test_f1_macro  test_balanced_accuracy  test_mcc  \
# 0       0.592747       0.204762                0.216071  0.214161
# 1       0.586628       0.254020                0.262825  0.267260
# 2       0.301878       0.374784                0.407576  0.374728
#
#    test_cohen_kappa  search_time_sec  n_jobs_search
# 0          0.209809            2.454              4
# 1          0.262966            2.660              4
# 2          0.370748            1.339              4
#
# [3 rows x 24 columns]
#    [+] Log leído: log_pcsmote_heart_D75_R25_Pproporcion.csv  (filas=5)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0   heart      0             128               102  no se sobremuestrea
# 1   heart      1              43               102      sobremuestreada
# 2   heart      2              28               102      sobremuestreada
# 3   heart      3              28               102      sobremuestreada
# 4   heart      4              10               102      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1                              ok                             59
# 2                              ok                             74
# 3                              ok                             74
# 4         insuficientes_filtradas                              0
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             237              237        0.540084  ...              NaN
# 1             237              296        0.181435  ...              0.1
# 2             237              370        0.118143  ...              0.0
# 3             237              444        0.118143  ...              0.0
# 4             237              444        0.042194  ...              0.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                75.0              25.0       proporcion
# 1              NaN                75.0              25.0       proporcion
# 2              NaN                75.0              25.0       proporcion
# 3              NaN                75.0              25.0       proporcion
# 4              NaN                75.0              25.0       proporcion
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
# 2                PCSMOTE                0.8            42             2d
# 3                PCSMOTE                0.8            42             2d
# 4                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:24.522759
# 1  2025-08-20T00:20:24.534585
# 2  2025-08-20T00:20:24.567022
# 3  2025-08-20T00:20:24.598169
# 4  2025-08-20T00:20:24.603169
#
# [5 rows x 27 columns]
#    [+] Log leído: log_pcsmote_heart_D75_R50_Pproporcion.csv  (filas=5)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0   heart      0             128               102  no se sobremuestrea
# 1   heart      1              43               102      sobremuestreada
# 2   heart      2              28               102      sobremuestreada
# 3   heart      3              28               102      sobremuestreada
# 4   heart      4              10               102      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1                              ok                             59
# 2                              ok                             74
# 3                              ok                             74
# 4         insuficientes_filtradas                              0
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             237              237        0.540084  ...              NaN
# 1             237              296        0.181435  ...              0.1
# 2             237              370        0.118143  ...              0.0
# 3             237              444        0.118143  ...              0.0
# 4             237              444        0.042194  ...              0.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                75.0              50.0       proporcion
# 1              NaN                75.0              50.0       proporcion
# 2              NaN                75.0              50.0       proporcion
# 3              NaN                75.0              50.0       proporcion
# 4              NaN                75.0              50.0       proporcion
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
# 2                PCSMOTE                0.8            42             2d
# 3                PCSMOTE                0.8            42             2d
# 4                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:25.103324
# 1  2025-08-20T00:20:25.134566
# 2  2025-08-20T00:20:25.181549
# 3  2025-08-20T00:20:25.204795
# 4  2025-08-20T00:20:25.204795
#
# [5 rows x 27 columns]
# ==========================================================================================
# Modelo: LogisticRegression | Dataset: statlog+shuttle
#  -> Sin filas para esta combinación.
# ==========================================================================================
# Modelo: RandomForest | Dataset: glass
#   dataset       tipo  tecnica  densidad  riesgo    pureza  n_train  n_test  \
# 0   glass  aumentado  pcsmote      50.0    25.0  entropia      268      43
# 1   glass  aumentado  pcsmote      25.0    25.0  entropia      268      43
# 2   glass       base     base       NaN     NaN       NaN      149      65
#
#    n_features  es_grande  ...  cv_f1_macro  cv_balanced_accuracy    cv_mcc  \
# 0           9      False  ...     0.848794              0.864121  0.814010
# 1           9      False  ...     0.845942              0.860417  0.809530
# 2           9      False  ...     0.669128              0.711734  0.662073
#
#   cv_cohen_kappa  test_f1_macro  test_balanced_accuracy  test_mcc  \
# 0       0.811109       0.771401                0.837302  0.729862
# 1       0.806363       0.728095                0.815079  0.678304
# 2       0.653424       0.796235                0.830067  0.777494
#
#    test_cohen_kappa  search_time_sec  n_jobs_search
# 0          0.725532            8.004              4
# 1          0.669462            8.058              4
# 2          0.772293            9.738              4
#
# [3 rows x 24 columns]
#    [+] Log leído: log_pcsmote_glass_D50_R25_Pentropia.csv  (filas=6)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0   glass      1              56                48  no se sobremuestrea
# 1   glass      2              61                48  no se sobremuestrea
# 2   glass      3              14                48      sobremuestreada
# 3   glass      5              10                48      sobremuestreada
# 4   glass      6               7                48      sobremuestreada
# 5   glass      7              23                48      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1  sin_faltante(actual>=objetivo)                              0
# 2                              ok                             34
# 3                              ok                             38
# 4         insuficientes_filtradas                              0
# 5                              ok                             25
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             171              171        0.327485  ...              NaN
# 1             171              171        0.356725  ...              NaN
# 2             171              205        0.081871  ...              1.0
# 3             171              243        0.058480  ...              0.0
# 4             171              243        0.040936  ...              0.4
# 5             171              268        0.134503  ...              1.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                50.0              25.0         entropia
# 1              NaN                50.0              25.0         entropia
# 2         0.721928                50.0              25.0         entropia
# 3         0.908695                50.0              25.0         entropia
# 4         0.970951                50.0              25.0         entropia
# 5         0.000000                50.0              25.0         entropia
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
# 2                PCSMOTE                0.8            42             2d
# 3                PCSMOTE                0.8            42             2d
# 4                PCSMOTE                0.8            42             2d
# 5                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:20.002049
# 1  2025-08-20T00:20:20.002049
# 2  2025-08-20T00:20:20.046713
# 3  2025-08-20T00:20:20.072602
# 4  2025-08-20T00:20:20.084190
# 5  2025-08-20T00:20:20.125995
#
# [6 rows x 27 columns]
#    [+] Log leído: log_pcsmote_glass_D25_R25_Pentropia.csv  (filas=6)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0   glass      1              56                48  no se sobremuestrea
# 1   glass      2              61                48  no se sobremuestrea
# 2   glass      3              14                48      sobremuestreada
# 3   glass      5              10                48      sobremuestreada
# 4   glass      6               7                48      sobremuestreada
# 5   glass      7              23                48      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1  sin_faltante(actual>=objetivo)                              0
# 2                              ok                             34
# 3                              ok                             38
# 4         insuficientes_filtradas                              0
# 5                              ok                             25
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             171              171        0.327485  ...              NaN
# 1             171              171        0.356725  ...              NaN
# 2             171              205        0.081871  ...              0.3
# 3             171              243        0.058480  ...              0.0
# 4             171              243        0.040936  ...              0.1
# 5             171              268        0.134503  ...              0.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                25.0              25.0         entropia
# 1              NaN                25.0              25.0         entropia
# 2         0.721928                25.0              25.0         entropia
# 3         0.908695                25.0              25.0         entropia
# 4         0.970951                25.0              25.0         entropia
# 5         0.000000                25.0              25.0         entropia
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
# 2                PCSMOTE                0.8            42             2d
# 3                PCSMOTE                0.8            42             2d
# 4                PCSMOTE                0.8            42             2d
# 5                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:19.359335
# 1  2025-08-20T00:20:19.359335
# 2  2025-08-20T00:20:19.392649
# 3  2025-08-20T00:20:19.440784
# 4  2025-08-20T00:20:19.461667
# 5  2025-08-20T00:20:19.549333
#
# [6 rows x 27 columns]
# ==========================================================================================
# Modelo: RandomForest | Dataset: ecoli
#  -> Sin filas para esta combinación.
# ==========================================================================================
# Modelo: RandomForest | Dataset: wdbc
#   dataset       tipo  tecnica  densidad  riesgo    pureza  n_train  n_test  \
# 0    wdbc  aumentado  pcsmote      25.0    25.0  entropia      513     114
# 1    wdbc  aumentado  pcsmote      75.0    25.0  entropia      513     114
# 2    wdbc       base     base       NaN     NaN       NaN      398     171
#
#    n_features  es_grande  ...  cv_f1_macro  cv_balanced_accuracy    cv_mcc  \
# 0          30      False  ...     0.962338              0.961714  0.925169
# 1          30      False  ...     0.962338              0.961714  0.925169
# 2          30      False  ...     0.938521              0.939862  0.881472
#
#   cv_cohen_kappa  test_f1_macro  test_balanced_accuracy  test_mcc  \
# 0       0.924691       0.971277                0.964286  0.944155
# 1       0.924691       0.971277                0.964286  0.944155
# 2       0.877487       0.962045                0.956265  0.925319
#
#    test_cohen_kappa  search_time_sec  n_jobs_search
# 0          0.942598           11.404              4
# 1          0.942598           11.791              4
# 2          0.924135           11.862              4
#
# [3 rows x 24 columns]
#    [+] Log leído: log_pcsmote_wdbc_D25_R25_Pentropia.csv  (filas=2)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0    wdbc      0             285               228  no se sobremuestrea
# 1    wdbc      1             170               228      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1                              ok                             58
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             455              455        0.626374  ...              NaN
# 1             455              513        0.373626  ...              0.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                25.0              25.0         entropia
# 1              0.0                25.0              25.0         entropia
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:15.388961
# 1  2025-08-20T00:20:15.506615
#
# [2 rows x 27 columns]
#    [+] Log leído: log_pcsmote_wdbc_D75_R25_Pentropia.csv  (filas=2)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0    wdbc      0             285               228  no se sobremuestrea
# 1    wdbc      1             170               228      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1                              ok                             58
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             455              455        0.626374  ...              NaN
# 1             455              513        0.373626  ...              0.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                75.0              25.0         entropia
# 1              0.0                75.0              25.0         entropia
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:18.274574
# 1  2025-08-20T00:20:18.481260
#
# [2 rows x 27 columns]
# ==========================================================================================
# Modelo: RandomForest | Dataset: heart
#   dataset       tipo  tecnica  densidad  riesgo    pureza  n_train  n_test  \
# 0   heart  aumentado  pcsmote      75.0    25.0  entropia      536      60
# 1   heart  aumentado  pcsmote      75.0    50.0  entropia      536      60
# 2   heart       base     base       NaN     NaN       NaN      207      90
#
#    n_features  es_grande  ...  cv_f1_macro  cv_balanced_accuracy    cv_mcc  \
# 0          13      False  ...     0.820912              0.821326  0.782944
# 1          13      False  ...     0.781551              0.783231  0.737928
# 2          13      False  ...     0.391340              0.404745  0.409880
#
#   cv_cohen_kappa  test_f1_macro  test_balanced_accuracy  test_mcc  \
# 0       0.779951       0.242262                0.262825  0.293920
# 1       0.735111       0.325044                0.348539  0.370465
# 2       0.401425       0.235370                0.250379  0.259336
#
#    test_cohen_kappa  search_time_sec  n_jobs_search
# 0          0.289785            9.252              4
# 1          0.367589            9.991              4
# 2          0.255759           10.475              4
#
# [3 rows x 24 columns]
#    [+] Log leído: log_pcsmote_heart_D75_R25_Pentropia.csv  (filas=5)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0   heart      0             128               102  no se sobremuestrea
# 1   heart      1              43               102      sobremuestreada
# 2   heart      2              28               102      sobremuestreada
# 3   heart      3              28               102      sobremuestreada
# 4   heart      4              10               102      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1                              ok                             59
# 2                              ok                             74
# 3                              ok                             74
# 4                              ok                             92
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             237              237        0.540084  ...              NaN
# 1             237              296        0.181435  ...              0.1
# 2             237              370        0.118143  ...              0.0
# 3             237              444        0.118143  ...              0.0
# 4             237              536        0.042194  ...              0.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                75.0              25.0         entropia
# 1         0.970951                75.0              25.0         entropia
# 2         0.970951                75.0              25.0         entropia
# 3         0.970951                75.0              25.0         entropia
# 4         0.541446                75.0              25.0         entropia
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
# 2                PCSMOTE                0.8            42             2d
# 3                PCSMOTE                0.8            42             2d
# 4                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:24.174921
# 1  2025-08-20T00:20:24.259831
# 2  2025-08-20T00:20:24.377767
# 3  2025-08-20T00:20:24.433553
# 4  2025-08-20T00:20:24.468936
#
# [5 rows x 27 columns]
#    [+] Log leído: log_pcsmote_heart_D75_R50_Pentropia.csv  (filas=5)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0   heart      0             128               102  no se sobremuestrea
# 1   heart      1              43               102      sobremuestreada
# 2   heart      2              28               102      sobremuestreada
# 3   heart      3              28               102      sobremuestreada
# 4   heart      4              10               102      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1                              ok                             59
# 2                              ok                             74
# 3                              ok                             74
# 4                              ok                             92
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             237              237        0.540084  ...              NaN
# 1             237              296        0.181435  ...              0.1
# 2             237              370        0.118143  ...              0.0
# 3             237              444        0.118143  ...              0.0
# 4             237              536        0.042194  ...              0.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                75.0              50.0         entropia
# 1         0.970951                75.0              50.0         entropia
# 2         0.970951                75.0              50.0         entropia
# 3         0.970951                75.0              50.0         entropia
# 4         0.541446                75.0              50.0         entropia
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
# 2                PCSMOTE                0.8            42             2d
# 3                PCSMOTE                0.8            42             2d
# 4                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:24.642846
# 1  2025-08-20T00:20:24.704649
# 2  2025-08-20T00:20:24.759767
# 3  2025-08-20T00:20:24.842111
# 4  2025-08-20T00:20:25.054068
#
# [5 rows x 27 columns]
# ==========================================================================================
# Modelo: RandomForest | Dataset: statlog+shuttle
#  -> Sin filas para esta combinación.
# ==========================================================================================
# Modelo: SVM | Dataset: glass
#   dataset       tipo  tecnica  densidad  riesgo    pureza  n_train  n_test  \
# 0   glass  aumentado  pcsmote      50.0    75.0  entropia      268      43
# 1   glass  aumentado  pcsmote      50.0    50.0  entropia      268      43
# 2   glass       base     base       NaN     NaN       NaN      149      65
#
#    n_features  es_grande  ...  cv_f1_macro  cv_balanced_accuracy    cv_mcc  \
# 0           9      False  ...     0.775106              0.787499  0.681754
# 1           9      False  ...     0.771263              0.789138  0.684204
# 2           9      False  ...     0.625198              0.644848  0.477330
#
#   cv_cohen_kappa  test_f1_macro  test_balanced_accuracy  test_mcc  \
# 0       0.676994       0.672687                0.744444  0.514037
# 1       0.677741       0.690087                0.755556  0.528990
# 2       0.468208       0.691925                0.769611  0.567833
#
#    test_cohen_kappa  search_time_sec  n_jobs_search
# 0          0.497595            0.175              4
# 1          0.519217            0.162              4
# 2          0.548475            0.202              4
#
# [3 rows x 24 columns]
#    [+] Log leído: log_pcsmote_glass_D50_R75_Pentropia.csv  (filas=6)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0   glass      1              56                48  no se sobremuestrea
# 1   glass      2              61                48  no se sobremuestrea
# 2   glass      3              14                48      sobremuestreada
# 3   glass      5              10                48      sobremuestreada
# 4   glass      6               7                48      sobremuestreada
# 5   glass      7              23                48      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1  sin_faltante(actual>=objetivo)                              0
# 2                              ok                             34
# 3                              ok                             38
# 4         insuficientes_filtradas                              0
# 5                              ok                             25
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             171              171        0.327485  ...              NaN
# 1             171              171        0.356725  ...              NaN
# 2             171              205        0.081871  ...              1.0
# 3             171              243        0.058480  ...              0.0
# 4             171              243        0.040936  ...              0.4
# 5             171              268        0.134503  ...              1.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                50.0              75.0         entropia
# 1              NaN                50.0              75.0         entropia
# 2         0.721928                50.0              75.0         entropia
# 3         0.908695                50.0              75.0         entropia
# 4         0.970951                50.0              75.0         entropia
# 5         0.000000                50.0              75.0         entropia
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
# 2                PCSMOTE                0.8            42             2d
# 3                PCSMOTE                0.8            42             2d
# 4                PCSMOTE                0.8            42             2d
# 5                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:20.355378
# 1  2025-08-20T00:20:20.355378
# 2  2025-08-20T00:20:20.371021
# 3  2025-08-20T00:20:20.407391
# 4  2025-08-20T00:20:20.419469
# 5  2025-08-20T00:20:20.439729
#
# [6 rows x 27 columns]
#    [+] Log leído: log_pcsmote_glass_D50_R50_Pentropia.csv  (filas=6)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0   glass      1              56                48  no se sobremuestrea
# 1   glass      2              61                48  no se sobremuestrea
# 2   glass      3              14                48      sobremuestreada
# 3   glass      5              10                48      sobremuestreada
# 4   glass      6               7                48      sobremuestreada
# 5   glass      7              23                48      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1  sin_faltante(actual>=objetivo)                              0
# 2                              ok                             34
# 3                              ok                             38
# 4         insuficientes_filtradas                              0
# 5                              ok                             25
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             171              171        0.327485  ...              NaN
# 1             171              171        0.356725  ...              NaN
# 2             171              205        0.081871  ...              1.0
# 3             171              243        0.058480  ...              0.0
# 4             171              243        0.040936  ...              0.4
# 5             171              268        0.134503  ...              1.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                50.0              50.0         entropia
# 1              NaN                50.0              50.0         entropia
# 2         0.721928                50.0              50.0         entropia
# 3         0.908695                50.0              50.0         entropia
# 4         0.970951                50.0              50.0         entropia
# 5         0.000000                50.0              50.0         entropia
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
# 2                PCSMOTE                0.8            42             2d
# 3                PCSMOTE                0.8            42             2d
# 4                PCSMOTE                0.8            42             2d
# 5                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:20.213901
# 1  2025-08-20T00:20:20.213901
# 2  2025-08-20T00:20:20.236255
# 3  2025-08-20T00:20:20.256254
# 4  2025-08-20T00:20:20.264720
# 5  2025-08-20T00:20:20.272963
#
# [6 rows x 27 columns]
# ==========================================================================================
# Modelo: SVM | Dataset: ecoli
#  -> Sin filas para esta combinación.
# ==========================================================================================
# Modelo: SVM | Dataset: wdbc
#   dataset       tipo  tecnica  densidad  riesgo    pureza  n_train  n_test  \
# 0    wdbc  aumentado  pcsmote      25.0    25.0  entropia      513     114
# 1    wdbc  aumentado  pcsmote      25.0    50.0  entropia      513     114
# 2    wdbc       base     base       NaN     NaN       NaN      398     171
#
#    n_features  es_grande  ...  cv_f1_macro  cv_balanced_accuracy    cv_mcc  \
# 0          30      False  ...     0.974203              0.973176  0.948979
# 1          30      False  ...     0.974203              0.973176  0.948979
# 2          30      False  ...     0.967628              0.966322  0.935679
#
#   cv_cohen_kappa  test_f1_macro  test_balanced_accuracy  test_mcc  \
# 0       0.948425       0.961486                0.952381  0.925820
# 1       0.948425       0.961486                0.952381  0.925820
# 2       0.935268       0.961773                0.953125  0.926353
#
#    test_cohen_kappa  search_time_sec  n_jobs_search
# 0          0.923077            0.319              4
# 1          0.923077            0.282              4
# 2          0.923649            0.192              4
#
# [3 rows x 24 columns]
#    [+] Log leído: log_pcsmote_wdbc_D25_R25_Pentropia.csv  (filas=2)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0    wdbc      0             285               228  no se sobremuestrea
# 1    wdbc      1             170               228      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1                              ok                             58
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             455              455        0.626374  ...              NaN
# 1             455              513        0.373626  ...              0.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                25.0              25.0         entropia
# 1              0.0                25.0              25.0         entropia
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:15.388961
# 1  2025-08-20T00:20:15.506615
#
# [2 rows x 27 columns]
#    [+] Log leído: log_pcsmote_wdbc_D25_R50_Pentropia.csv  (filas=2)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0    wdbc      0             285               228  no se sobremuestrea
# 1    wdbc      1             170               228      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1                              ok                             58
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             455              455        0.626374  ...              NaN
# 1             455              513        0.373626  ...              0.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                25.0              50.0         entropia
# 1              0.0                25.0              50.0         entropia
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:15.690957
# 1  2025-08-20T00:20:15.862442
#
# [2 rows x 27 columns]
# ==========================================================================================
# Modelo: SVM | Dataset: heart
#   dataset       tipo  tecnica  densidad  riesgo      pureza  n_train  n_test  \
# 0   heart  aumentado  pcsmote      75.0    25.0    entropia      536      60
# 1   heart  aumentado  pcsmote      75.0    50.0  proporcion      444      60
# 2   heart       base     base       NaN     NaN         NaN      207      90
#
#    n_features  es_grande  ...  cv_f1_macro  cv_balanced_accuracy    cv_mcc  \
# 0          13      False  ...     0.630694              0.639890  0.559117
# 1          13      False  ...     0.616348              0.625111  0.643214
# 2          13      False  ...     0.324389              0.331935  0.258524
#
#   cv_cohen_kappa  test_f1_macro  test_balanced_accuracy  test_mcc  \
# 0       0.555749       0.329349                0.336039  0.344508
# 1       0.638321       0.376471                0.374513  0.416751
# 2       0.255080       0.334528                0.325758  0.307721
#
#    test_cohen_kappa  search_time_sec  n_jobs_search
# 0          0.342327            0.343              4
# 1          0.413854            0.275              4
# 2          0.306893            0.222              4
#
# [3 rows x 24 columns]
#    [+] Log leído: log_pcsmote_heart_D75_R25_Pentropia.csv  (filas=5)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0   heart      0             128               102  no se sobremuestrea
# 1   heart      1              43               102      sobremuestreada
# 2   heart      2              28               102      sobremuestreada
# 3   heart      3              28               102      sobremuestreada
# 4   heart      4              10               102      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1                              ok                             59
# 2                              ok                             74
# 3                              ok                             74
# 4                              ok                             92
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             237              237        0.540084  ...              NaN
# 1             237              296        0.181435  ...              0.1
# 2             237              370        0.118143  ...              0.0
# 3             237              444        0.118143  ...              0.0
# 4             237              536        0.042194  ...              0.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                75.0              25.0         entropia
# 1         0.970951                75.0              25.0         entropia
# 2         0.970951                75.0              25.0         entropia
# 3         0.970951                75.0              25.0         entropia
# 4         0.541446                75.0              25.0         entropia
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
# 2                PCSMOTE                0.8            42             2d
# 3                PCSMOTE                0.8            42             2d
# 4                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:24.174921
# 1  2025-08-20T00:20:24.259831
# 2  2025-08-20T00:20:24.377767
# 3  2025-08-20T00:20:24.433553
# 4  2025-08-20T00:20:24.468936
#
# [5 rows x 27 columns]
#    [+] Log leído: log_pcsmote_heart_D75_R50_Pproporcion.csv  (filas=5)
#   dataset  clase  train_original  objetivo_balance               estado  \
# 0   heart      0             128               102  no se sobremuestrea
# 1   heart      1              43               102      sobremuestreada
# 2   heart      2              28               102      sobremuestreada
# 3   heart      3              28               102      sobremuestreada
# 4   heart      4              10               102      sobremuestreada
#
#             motivo_sin_sinteticas  muestras_sinteticas_generadas  \
# 0  sin_faltante(actual>=objetivo)                              0
# 1                              ok                             59
# 2                              ok                             74
# 3                              ok                             74
# 4         insuficientes_filtradas                              0
#
#    total_original  total_resampled  ratio_original  ...  umbral_densidad  \
# 0             237              237        0.540084  ...              NaN
# 1             237              296        0.181435  ...              0.1
# 2             237              370        0.118143  ...              0.0
# 3             237              444        0.118143  ...              0.0
# 4             237              444        0.042194  ...              0.0
#
#    umbral_entropia  percentil_densidad  percentil_riesgo  criterio_pureza  \
# 0              NaN                75.0              50.0       proporcion
# 1              NaN                75.0              50.0       proporcion
# 2              NaN                75.0              50.0       proporcion
# 3              NaN                75.0              50.0       proporcion
# 4              NaN                75.0              50.0       proporcion
#
#    tecnica_sobremuestreo  factor_equilibrio  random_state  modo_espacial  \
# 0                PCSMOTE                0.8            42             2d
# 1                PCSMOTE                0.8            42             2d
# 2                PCSMOTE                0.8            42             2d
# 3                PCSMOTE                0.8            42             2d
# 4                PCSMOTE                0.8            42             2d
#
#                     timestamp
# 0  2025-08-20T00:20:25.103324
# 1  2025-08-20T00:20:25.134566
# 2  2025-08-20T00:20:25.181549
# 3  2025-08-20T00:20:25.204795
# 4  2025-08-20T00:20:25.204795
#
# [5 rows x 27 columns]
# ==========================================================================================
# Modelo: SVM | Dataset: statlog+shuttle
#  -> Sin filas para esta combinación.

# %%
import pandas as pd

EXPORTAR_EXCEL = True

if EXPORTAR_EXCEL:
    RUTA_XLSX_SALIDA.parent.mkdir(parents=True, exist_ok=True)
    with pd.ExcelWriter(RUTA_XLSX_SALIDA, engine="xlsxwriter") as xw:
        # Formatos
        fmt_border = xw.book.add_format({'border': 1})
        fmt_wrap   = xw.book.add_format({'text_wrap': True, 'valign': 'top', 'border': 1})
        fmt_title  = xw.book.add_format({'bold': True})

        # ===== Hojas TOP por MODELO (una hoja por modelo; múltiples datasets) =====
        for modelo, bloques in bloques_por_modelo.items():
            sheet_name = ajustar_nombre(f"top+{alias_modelo(modelo)}")
            # Worksheet se crea al primer to_excel
            # Para calcular anchos: concateno todos los bloques (solo para sizing)
            df_all = pd.concat([df for _, df in bloques], ignore_index=True) if bloques else pd.DataFrame()

            start_row = 0
            for ds, df in bloques:
                # Rótulo de dataset
                ws = xw.book.add_worksheet(sheet_name) if sheet_name not in xw.sheets else xw.sheets[sheet_name]
                if start_row == 0 and sheet_name not in xw.sheets:
                    # si recién se creó, registrar
                    xw.sheets[sheet_name] = ws
                else:
                    ws = xw.sheets[sheet_name]

                ws.write(start_row, 0, f"Dataset: {ds}", fmt_title)
                start_row += 1

                # Escribir bloque con cabecera
                df.to_excel(xw, sheet_name=sheet_name, startrow=start_row, index=False, header=True)
                start_row += len(df) + 2  # una fila en blanco entre bloques

            # Ajustes de columnas (sobre df_all)
            if not df_all.empty:
                ws = xw.sheets[sheet_name]
                # Columna N (índice 13)
                ws.set_column(13, 13, 38, fmt_wrap)
                # Resto auto-ajuste + borde
                for idx, col in enumerate(df_all.columns):
                    if idx == 13:
                        continue
                    max_len = max([len(str(col))] + [len(str(v)) for v in df_all[col].astype(str)])
                    ancho = min(max_len + 2, 50)
                    ws.set_column(idx, idx, ancho, fmt_border)

        # ===== Hojas de LOGS (misma lógica que ya usabas) =====
        for name, logdf in logs_encontrados:
            sheet = ajustar_nombre(name)
            logdf.to_excel(xw, index=False, sheet_name=sheet)
            ws = xw.sheets[sheet]
            for idx, col in enumerate(logdf.columns):
                max_len = max([len(str(col))] + [len(str(v)) for v in logdf[col].astype(str)])
                ancho = min(max_len + 2, 50)
                ws.set_column(idx, idx, ancho, fmt_border)

    print(f"[i] Exportado a: {RUTA_XLSX_SALIDA.resolve()}")
else:
    print("Exportación a Excel desactivada (EXPORTAR_EXCEL=False).")
# Out:
# [i] Exportado a: C:\Users\FamiliaNatelloMedina\Documents\UNLu\armado-tesina\codigo\resultados\estudio_de_resultados.xlsx
